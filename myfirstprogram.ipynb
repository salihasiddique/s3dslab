# %%
a=5
print(a)
print(type(a))
# Out:
# 5
# <class 'int'>

# %%
 import matplotlib.pyplot as plt
 x=[1,5,4]
y=[6,4,1]
plt.plot( x , y , linewidth=4)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('my first graph!')
plt.show()
